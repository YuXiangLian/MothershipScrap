# %%
# !jupyter nbconvert --to script Mothership_web_scraper.ipynb
# Out:
# [NbConvertApp] Converting notebook Mothership_web_scraper.ipynb to script
# [NbConvertApp] Writing 6170 bytes to Mothership_web_scraper.py

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests 
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

# %%
def get_data(url,keywords,title,url_keep,date,text,keyfound):
    source = requests.get(url).content
    soup = BeautifulSoup(source,"lxml")
    
    content = soup.find_all("div",class_ = "content-article-wrap")
    headline = soup.find('h1').text
    date1 = soup.find("span",class_="publish-date").text.strip("n\n")
    related_article = False
    body_text = content[0].text.replace('\n',' ').replace('\r','').replace("\xa0"," ")
    key = []
    for keyword in keywords:
        if keyword in headline.lower():
            related_article = True
            key.append(keyword)
        if keyword in body_text.lower():
            related_article = True
            key.append(keyword)
    if related_article :
        title.append(headline)
        url_keep.append(url)
        date.append(date1)
        text.append(body_text)
        keyfound.append(key)

# %%
def get_covid_news(url,related_url):
    source = requests.get(url).content
    soup = BeautifulSoup(source,"lxml")
    
    content = soup.find_all("div",class_ = "content-article-wrap")
    headline = soup.find('h1').text
    date1 = soup.find("span",class_="publish-date").text.strip("n\n")
    related_article = False
    body_text = content[0].text.replace('\n',' ').replace('\r','').replace("\xa0"," ")
    key = ['nCov', 'virus', 'Virus', 'coronavirus', 'Coronavirus', 'wuhan', 'Wuhan', '2019-ncov','covid','covid-19']
    for keyword in key:
        if keyword in headline.lower():
            related_article = True
        if keyword in body_text.lower():
            related_article = True
    if related_article :
        related_url.append(url)

# %%
#scraping via covid 19 tag and searching headlines and body text for mental health keywords
path = "C:\Program Files\chromedriver.exe"
url = "https://mothership.sg/tag/covid-19/"

driver = webdriver.Chrome(path)
driver.get(url)


while True:
    try:
        load = driver.find_element_by_id("load-stories")
        load.click()
        sleep(1)
    except Exception as e:
        print("complete")
        break
sleep(3)

urls_1 = []


for div in driver.find_elements_by_class_name('ind-article'):
    for a in div.find_elements_by_tag_name('a'):
        if "mothership.sg" in a.get_attribute("href"):
            print(a.get_attribute("href"))
            urls_1.append(a.get_attribute("href"))
driver.close()
urls_1
# Out:
# complete
# https://mothership.sg/2021/07/covid-19-testing-compulsory-higher-risk-testing-singapore/
# https://mothership.sg/2021/07/ong-ye-kung-covid-19-vaccines-delta-efficacy/
# https://mothership.sg/2021/07/vaccinated-persons-measures-singapore/
# https://mothership.sg/2021/07/work-from-home-default-phase-3/
# https://mothership.sg/2021/07/gym-indoor-mask-off-activities/
# https://mothership.sg/2021/07/dining-in-from-july-21/
# https://mothership.sg/2021/07/students-no-physical-activity/
# https://mothership.sg/2021/07/july-6-covid-evening-update/
# https://mothership.sg/2021/07/july-6-covid-update/
# https://mothership.sg/2021/07/mbs-badge-woman-new-charges/
# https://mothership.sg/2021/07/work-from-home-default-phase-3/
# https://mothership.sg/2021/07/gym-indoor-mask-off-activities/
# https://mothership.sg/2021/07/dining-in-from-july-21/
# https://mothership.sg/2021/07/ang-mo-kio-fire-50-evacuated-pma/
# https://mothership.sg/2021/07/chef-crackling-orn-nee-bao/
# https://mothership.sg/2021/07/set-up-box-illegal-singapore/
# https://mothership.sg/2021/07/women-sitting-on-johor-ledge/
# https://mothership.sg/2021/07/pritam-teo-chee-hean-eip-cmio/
# https://mothership.sg/2021/07/singapore-police-arrested-man-statement-debunk/
# https://mothership.sg/2021/07/eip-debate-parliament/
# https://mothership.sg/2021/07/covid-19-july-5-night-update/
# https://mothership.sg/2021/07/sq351-diverted-copenhagen/
# https://mothership.sg/2021/07/racial-harmony-edwin-tong-parliament/
# https://mothership.sg/2021/07/ns-men-virtual-fitness/
# https://mothership.sg/2021/07/groups-of-5-dining-in-lawrence-wong/
# https://mothership.sg/2021/07/next-of-kin-ho-kong-chan/
# https://mothership.sg/2021/07/louis-ng-marine-wildlife-act-horseshoe-crabs/
# https://mothership.sg/2021/07/pritam-teo-chee-hean-eip-cmio/
# https://mothership.sg/2021/07/singapore-police-arrested-man-statement-debunk/
# https://mothership.sg/2021/07/eip-debate-parliament/
# https://mothership.sg/2021/07/covid-19-july-5-night-update/
# https://mothership.sg/2021/07/sq351-diverted-copenhagen/
# https://mothership.sg/2021/07/racial-harmony-edwin-tong-parliament/
# https://mothership.sg/2021/07/ns-men-virtual-fitness/
# https://mothership.sg/2021/07/groups-of-5-dining-in-lawrence-wong/
# ['https://mothership.sg/2021/07/covid-19-testing-compulsory-higher-risk-testing-singapore/',
#  'https://mothership.sg/2021/07/ong-ye-kung-covid-19-vaccines-delta-efficacy/',
#  'https://mothership.sg/2021/07/vaccinated-persons-measures-singapore/',
#  'https://mothership.sg/2021/07/work-from-home-default-phase-3/',
#  'https://mothership.sg/2021/07/gym-indoor-mask-off-activities/',
#  'https://mothership.sg/2021/07/dining-in-from-july-21/',
#  'https://mothership.sg/2021/07/students-no-physical-activity/',
#  'https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/july-6-covid-update/',
#  'https://mothership.sg/2021/07/mbs-badge-woman-new-charges/',
#  'https://mothership.sg/2021/07/work-from-home-default-phase-3/',
#  'https://mothership.sg/2021/07/gym-indoor-mask-off-activities/',
#  'https://mothership.sg/2021/07/dining-in-from-july-21/',
#  'https://mothership.sg/2021/07/ang-mo-kio-fire-50-evacuated-pma/',
#  'https://mothership.sg/2021/07/chef-crackling-orn-nee-bao/',
#  'https://mothership.sg/2021/07/set-up-box-illegal-singapore/',
#  'https://mothership.sg/2021/07/women-sitting-on-johor-ledge/',
#  'https://mothership.sg/2021/07/implementation-of-asean-agreement-to-resolve-myanmar-crisis-is-slow-disappointing-vivian/',
#  'https://mothership.sg/2021/07/nus-computing-student-from-ite-em3/',
#  'https://mothership.sg/2021/07/japanese-woman-water-gun-olympic-torch-arrested/',
#  'https://mothership.sg/2021/07/students-no-physical-activity/',
#  'https://mothership.sg/2021/07/burger-king-gula-melaka-rendang-burger/',
#  'https://mothership.sg/2021/07/man-threw-pride-flag-lau-pa-sat-smol-conditional-warning/',
#  'https://mothership.sg/2021/07/fann-wongs-father-passes-away-at-age-81/',
#  'https://mothership.sg/2021/07/cotton-candy-machine-sembawang/',
#  'https://mothership.sg/2021/07/temasek-foundation-oximeter-exchange/',
#  'https://mothership.sg/2021/07/big-3d-cat-shinjuku/',
#  'https://mothership.sg/2021/07/how-to-choose-durians/',
#  'https://mothership.sg/2021/07/geylang-street-durian/',
#  'https://mothership.sg/2021/07/divorce-marriage-statistics-sg-2020/',
#  'https://mothership.sg/2021/07/can-home-based-business-receive-more-than-5-guests/',
#  'https://mothership.sg/2021/07/man-feeds-tissue-seller-singapore/',
#  'https://mothership.sg/2021/07/car-reverse-braddell-road/',
#  'https://mothership.sg/2021/07/temasek-oximeter-resell-carousell/',
#  'https://mothership.sg/2021/07/forest-soft-shell-turtle/',
#  'https://mothership.sg/2021/07/fake-money-singapore-dollars/',
#  'https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/ong-ye-jung-ceca-psp-withdraw-allegations/',
#  'https://mothership.sg/2021/07/heng-swee-keat-ceca-statement/',
#  'https://mothership.sg/2021/07/after-ong-ye-kung-exchanges-leong-mun-wai-accepts-free-movement-was-not-used-as-bargaining-chip-in-ceca/',
#  'https://mothership.sg/2021/07/can-home-based-business-receive-more-than-5-guests/',
#  'https://mothership.sg/2021/07/man-feeds-tissue-seller-singapore/',
#  'https://mothership.sg/2021/07/car-reverse-braddell-road/',
#  'https://mothership.sg/2021/07/temasek-oximeter-resell-carousell/',
#  'https://mothership.sg/2021/07/forest-soft-shell-turtle/',
#  'https://mothership.sg/2021/07/fake-money-singapore-dollars/',
#  'https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/ong-ye-jung-ceca-psp-withdraw-allegations/',
#  'https://mothership.sg/2021/07/heng-swee-keat-ceca-statement/',
#  'https://mothership.sg/2021/07/after-ong-ye-kung-exchanges-leong-mun-wai-accepts-free-movement-was-not-used-as-bargaining-chip-in-ceca/',
#  'https://mothership.sg/2021/07/taecyeon-stalkers-singapore-hotel/',
#  'https://mothership.sg/2021/07/make-up-pay-minister-teo-chee-hean-he-ting-ru/',
#  'https://mothership.sg/2021/07/the-witcher-mobile-game/',
#  'https://mothership.sg/2021/07/thebakingmunchies-ang-mo-kio/',
#  'https://mothership.sg/2021/07/cambodia-pet-lion-returns/',
#  'https://mothership.sg/2021/07/mbs-badge-woman-new-charges/',
#  'https://mothership.sg/2021/07/motorcycle-skid-crash-kje-trailer/',
#  'https://mothership.sg/2021/07/eip-essential-racial-harmony-desmond-lee/',
#  'https://mothership.sg/2021/07/food-from-the-heart-appeal-donations/',
#  'https://mothership.sg/2021/07/temporary-housing-hdb-bto-delays-mnd/',
#  'https://mothership.sg/2021/07/next-of-kin-ho-kong-chan/',
#  'https://mothership.sg/2021/07/louis-ng-marine-wildlife-act-horseshoe-crabs/',
#  'https://mothership.sg/2021/07/pritam-teo-chee-hean-eip-cmio/',
#  'https://mothership.sg/2021/07/singapore-police-arrested-man-statement-debunk/',
#  'https://mothership.sg/2021/07/eip-debate-parliament/',
#  'https://mothership.sg/2021/07/covid-19-july-5-night-update/',
#  'https://mothership.sg/2021/07/sq351-diverted-copenhagen/',
#  'https://mothership.sg/2021/07/racial-harmony-edwin-tong-parliament/',
#  'https://mothership.sg/2021/07/ns-men-virtual-fitness/',
#  'https://mothership.sg/2021/07/groups-of-5-dining-in-lawrence-wong/',
#  'https://mothership.sg/2021/07/next-of-kin-ho-kong-chan/',
#  'https://mothership.sg/2021/07/louis-ng-marine-wildlife-act-horseshoe-crabs/',
#  'https://mothership.sg/2021/07/pritam-teo-chee-hean-eip-cmio/',
#  'https://mothership.sg/2021/07/singapore-police-arrested-man-statement-debunk/',
#  'https://mothership.sg/2021/07/eip-debate-parliament/',
#  'https://mothership.sg/2021/07/covid-19-july-5-night-update/',
#  'https://mothership.sg/2021/07/sq351-diverted-copenhagen/',
#  'https://mothership.sg/2021/07/racial-harmony-edwin-tong-parliament/',
#  'https://mothership.sg/2021/07/ns-men-virtual-fitness/',
#  'https://mothership.sg/2021/07/groups-of-5-dining-in-lawrence-wong/']

# %%
related_urls_1 = []
for url in urls_1:
    get_covid_news(url,related_urls_1)
related_urls_1
# Out:
# ['https://mothership.sg/2021/07/covid-19-testing-compulsory-higher-risk-testing-singapore/',
#  'https://mothership.sg/2021/07/ong-ye-kung-covid-19-vaccines-delta-efficacy/',
#  'https://mothership.sg/2021/07/vaccinated-persons-measures-singapore/',
#  'https://mothership.sg/2021/07/work-from-home-default-phase-3/',
#  'https://mothership.sg/2021/07/students-no-physical-activity/',
#  'https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/july-6-covid-update/',
#  'https://mothership.sg/2021/07/mbs-badge-woman-new-charges/',
#  'https://mothership.sg/2021/07/work-from-home-default-phase-3/',
#  'https://mothership.sg/2021/07/women-sitting-on-johor-ledge/',
#  'https://mothership.sg/2021/07/japanese-woman-water-gun-olympic-torch-arrested/',
#  'https://mothership.sg/2021/07/students-no-physical-activity/',
#  'https://mothership.sg/2021/07/geylang-street-durian/',
#  'https://mothership.sg/2021/07/divorce-marriage-statistics-sg-2020/',
#  'https://mothership.sg/2021/07/can-home-based-business-receive-more-than-5-guests/',
#  'https://mothership.sg/2021/07/temasek-oximeter-resell-carousell/',
#  'https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/heng-swee-keat-ceca-statement/',
#  'https://mothership.sg/2021/07/can-home-based-business-receive-more-than-5-guests/',
#  'https://mothership.sg/2021/07/temasek-oximeter-resell-carousell/',
#  'https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/heng-swee-keat-ceca-statement/',
#  'https://mothership.sg/2021/07/mbs-badge-woman-new-charges/',
#  'https://mothership.sg/2021/07/food-from-the-heart-appeal-donations/',
#  'https://mothership.sg/2021/07/temporary-housing-hdb-bto-delays-mnd/',
#  'https://mothership.sg/2021/07/covid-19-july-5-night-update/',
#  'https://mothership.sg/2021/07/groups-of-5-dining-in-lawrence-wong/',
#  'https://mothership.sg/2021/07/covid-19-july-5-night-update/',
#  'https://mothership.sg/2021/07/groups-of-5-dining-in-lawrence-wong/']

# %%
keyword = []
with open('Mental health kw.txt', 'r') as text:
    keyword.extend(text.readlines())
keywords = [k.strip("\n") for k in keyword]
keywords
for keyword in keywords :
    print(keyword)
# Out:
# depression
# mental illness
# unalive
# social anxiety
# loneliness
# stress
# lonely
# isolation
# suicide
# abuse
# death
# post traumatic stress disorder
# no motivation
# therapy
# trauma
# counselling
# mood disorder
# mood swings
# mental health
# angst
# emotion
# phobia
# addiction
# stigma
# self-harm
# neurosis
# abuse
# disorder
# dependence
# socialize
# help
# dead
# melancholia
# dysthemia
# tired
# trapped
# paranoia
# overwhelmed
# irritable
# bipolar
# psychologist
# well-being
# imh
# sos
# counsellor
# toxic
# insominia
# drugs
# fight
# self-esteem

# %%
title = []
url_keep = []
date = []
text = []
keyfound = []
for url in related_urls_1:
    get_data(url,keywords,title,url_keep,date,text,keyfound)

# %%
url_keep
# Out:
# ['https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/july-6-covid-update/',
#  'https://mothership.sg/2021/07/temasek-oximeter-resell-carousell/',
#  'https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/heng-swee-keat-ceca-statement/',
#  'https://mothership.sg/2021/07/temasek-oximeter-resell-carousell/',
#  'https://mothership.sg/2021/07/july-6-covid-evening-update/',
#  'https://mothership.sg/2021/07/heng-swee-keat-ceca-statement/',
#  'https://mothership.sg/2021/07/covid-19-july-5-night-update/',
#  'https://mothership.sg/2021/07/covid-19-july-5-night-update/']

# %%
import pandas as pd

# %%
def process_data(title,url_keep,date,text,keyfound):
    dataframe = pd.DataFrame()
    dataframe["headline"] = title[1:]
    dataframe["url"] = url_keep[1:]
    dataframe["date"] = date[1:]
    dataframe["text"] = text[1:]
    dataframe["keywords"] = keyfound[1:]
    return dataframe

# %%
d1 = process_data(title,url_keep,date,text,keyfound)
d1
# Out:
#                                             headline  \
# 0  2 locally-transmitted Covid-19 cases in S'pore...
# 1  Temasek Foundation's free oximeters sold on Ca...
# 2  1 dormitory resident among unlinked community ...
# 3  I spent 3 years of my life negotiating CECA to...
# 4  Temasek Foundation's free oximeters sold on Ca...
# 5  1 dormitory resident among unlinked community ...
# 6  I spent 3 years of my life negotiating CECA to...
# 7  1 new Covid-19 cluster in S'pore involving M's...
# 8  1 new Covid-19 cluster in S'pore involving M's...
#
#                                                  url  \
# 0  https://mothership.sg/2021/07/july-6-covid-upd...
# 1  https://mothership.sg/2021/07/temasek-oximeter...
# 2  https://mothership.sg/2021/07/july-6-covid-eve...
# 3  https://mothership.sg/2021/07/heng-swee-keat-c...
# 4  https://mothership.sg/2021/07/temasek-oximeter...
# 5  https://mothership.sg/2021/07/july-6-covid-eve...
# 6  https://mothership.sg/2021/07/heng-swee-keat-c...
# 7  https://mothership.sg/2021/07/covid-19-july-5-...
# 8  https://mothership.sg/2021/07/covid-19-july-5-...
#
#                        date  \
# 0  July 06, 2021, 04:09 PM
# 1  July 07, 2021, 12:04 AM
# 2  July 06, 2021, 10:23 PM
# 3  July 06, 2021, 08:13 PM
# 4  July 07, 2021, 12:04 AM
# 5  July 06, 2021, 10:23 PM
# 6  July 06, 2021, 08:13 PM
# 7  July 05, 2021, 10:06 PM
# 8  July 05, 2021, 10:06 PM
#
#                                                 text     keywords
# 0   Follow us on Telegram for the latest updates ...  [isolation]
# 1   Follow us on Telegram for the latest updates:...       [help]
# 2   Follow us on Telegram for the latest updates ...  [isolation]
# 3   Deputy Prime Minister Heng Swee Keat had not ...       [help]
# 4   Follow us on Telegram for the latest updates:...       [help]
# 5   Follow us on Telegram for the latest updates ...  [isolation]
# 6   Deputy Prime Minister Heng Swee Keat had not ...       [help]
# 7   Follow us on Telegram for the latest updates ...  [isolation]
# 8   Follow us on Telegram for the latest updates ...  [isolation]

# %%
url_1 = "https://mothership.sg/search/?s=covid+"

path = "C:\Program Files\chromedriver.exe"

url_search = []
for key in keywords:
    driver = webdriver.Chrome(path)
    driver.get(url_1 + key)



    while True:
        try:
            load = driver.find_element_by_id("load-more")
            load.click()
            sleep(1)
        except Exception as e:
            break
    sleep(3)


    for div in driver.find_elements_by_class_name('ind-article'):
        for a in div.find_elements_by_tag_name('a'):
            if "mothership.sg" in a.get_attribute("href"):
                print(a.get_attribute("href"))
                url_search.append(a.get_attribute("href"))
    
    driver.close()
 
print("all done")
# Out:
# all done
# all done
# all done
# all done
# all done
# all done
# all done
# https://mothership.sg/2020/03/covid-19-isolation-facility/
# https://mothership.sg/2020/04/expo-covid-19-isolation-facility/
# https://mothership.sg/2020/08/australia-victoria-deploy-military-covid-19/
# https://mothership.sg/2020/04/covid-19-isolation-facilities-capacity-singapore/
# https://mothership.sg/2020/05/highest-number-discharged-504-may-11/
# all done
# https://mothership.sg/2020/11/china-brazil-vaccine-suicide/
# https://mothership.sg/2020/03/german-minister-dead-covid-19/
# all done
# https://mothership.sg/2020/04/temporary-relief-fund-jail/
# all done
# https://mothership.sg/2020/12/us-covid-19-deaths-ww2/
# https://mothership.sg/2020/10/covid-28th-death-sg/
# https://mothership.sg/2021/04/covid-19-india-deaths/
# https://mothership.sg/2020/03/united-states-first-death-covid-19/
# https://mothership.sg/2021/05/may-1-covid-19-death/
# https://mothership.sg/2020/08/vietnam-second-covid-19-death/
# https://mothership.sg/2020/04/case-1064-death-heart-disease/
# https://mothership.sg/2020/07/covid-19-27th-death/
# https://mothership.sg/2020/04/us-overtakes-italy-deaths-covid-19/
# https://mothership.sg/2020/08/vietnam-first-covid-19-death/
# https://mothership.sg/2020/05/18-death-covid-19/
# https://mothership.sg/2020/03/australia-first-death-covid-19/
# https://mothership.sg/2021/02/russia-sputnik-v-vaccine-effective/
# https://mothership.sg/2020/06/june-6-covid-19-update/
# https://mothership.sg/2020/05/covid-19-update-may-1-death/
# https://mothership.sg/2020/05/covid-19-21st-death-singapore/
# https://mothership.sg/2020/04/covid-death-sixth/
# https://mothership.sg/2020/05/15th-covid-19-patient-death-singapore/
# https://mothership.sg/2020/09/singapore-covid-19-death-lowest/
# https://mothership.sg/2020/04/covid-death-12th/
# https://mothership.sg/2020/02/south-korea-763-cases-covid-19/
# https://mothership.sg/2020/03/iran-covid-19-death-toll-march-20/
# https://mothership.sg/2020/03/italy-covid-19/
# https://mothership.sg/2020/05/indian-worker-elderly-parents-sold-land/
# https://mothership.sg/2020/03/italy-covid-19-march-25/
# https://mothership.sg/2020/03/indonesia-first-covid-19-death/
# https://mothership.sg/2020/02/hong-kong-second-death-covid-19/
# https://mothership.sg/2020/03/psp-ge-anytime/
# all done
# all done

# %%
len(url_search)
# Out:
# 84

# %%
keywords2 = ["singapore"]
related_urls_2 =[]
for url in url_search:
    get_data(url,keywords2,[],related_urls_2,[],[],[])

# %%
len(related_urls_2)
# Out:
# 42

# %%
title1 = []
url_keep1 = []
date1 = []
text1 = []
keyfound1 = []
for url in related_urls_2:
    get_data(url,keywords,title1,url_keep1,date1,text1,keyfound1)
d2 = process_data(title1,url_keep1,date1,text1,keyfound1)

# %%
#scraping through search mental health then finding covid keywords
url_2 = "https://mothership.sg/search/?s=mental+health"

path = "C:\Program Files\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get(url_2)

url_mental = []

while True:
    try:
        load = driver.find_element_by_id("load-more")
        load.click()
        sleep(1)
    except Exception as e:
        print("complete")
        break
sleep(3)



for div in driver.find_elements_by_class_name('ind-article'):
    for a in div.find_elements_by_tag_name('a'):
        if "mothership.sg" in a.get_attribute("href"):
            print(a.get_attribute("href"))
            url_mental.append(a.get_attribute("href"))
driver.close()
url_mental
# Out:
# complete
# https://mothership.sg/2021/07/covid-19-survey-singaporeans-mental-health/
# https://mothership.sg/2020/01/mental-health-declaration/
# https://mothership.sg/2020/12/amk-hub-police-catch-woman-video/
# https://mothership.sg/2021/03/mental-health-bullying-moe-cos-2021/
# https://mothership.sg/2020/02/mental-health-budget-2020-anthea-ong/
# https://mothership.sg/2019/02/anthea-ong-mental-health-budget-2019/
# https://mothership.sg/2020/10/pm-lee-covid-19-mental-health/
# https://mothership.sg/2019/09/beyond-the-label-festival-mental-health/
# https://mothership.sg/2020/08/migrant-workers-mental-health-mom/
# https://mothership.sg/2020/11/chng-kai-fong/
# https://mothership.sg/2020/09/migrant-worker-mental-health/
# https://mothership.sg/2021/02/man-lock-himself-in-bendemeer-flat/
# https://mothership.sg/2020/03/mom-mental-health-sick-leave/
# https://mothership.sg/2020/03/moe-mental-health-in-curriculum/
# https://mothership.sg/2020/09/mental-health-during-covid-19/
# https://mothership.sg/2019/10/mental-health-ncss/
# https://mothership.sg/2020/12/naked-woman-at-bedok/
# https://mothership.sg/2017/06/prince-harrys-frank-conversation-with-local-youths-on-mental-health-is-something-we-can-learn-from/
# https://mothership.sg/2018/01/aunties-singapore-parkour/
# https://mothership.sg/2017/11/nearly-10-of-spore-residents-will-suffer-from-mental-health-issues-more-support-to-reduce-social-stigma/
# https://mothership.sg/2019/03/cpf-mental-health-treatment-savings/
# ['https://mothership.sg/2021/07/covid-19-survey-singaporeans-mental-health/',
#  'https://mothership.sg/2020/01/mental-health-declaration/',
#  'https://mothership.sg/2020/12/amk-hub-police-catch-woman-video/',
#  'https://mothership.sg/2021/03/mental-health-bullying-moe-cos-2021/',
#  'https://mothership.sg/2020/02/mental-health-budget-2020-anthea-ong/',
#  'https://mothership.sg/2019/02/anthea-ong-mental-health-budget-2019/',
#  'https://mothership.sg/2020/10/pm-lee-covid-19-mental-health/',
#  'https://mothership.sg/2019/09/beyond-the-label-festival-mental-health/',
#  'https://mothership.sg/2020/08/migrant-workers-mental-health-mom/',
#  'https://mothership.sg/2020/11/chng-kai-fong/',
#  'https://mothership.sg/2020/09/migrant-worker-mental-health/',
#  'https://mothership.sg/2021/02/man-lock-himself-in-bendemeer-flat/',
#  'https://mothership.sg/2020/03/mom-mental-health-sick-leave/',
#  'https://mothership.sg/2020/03/moe-mental-health-in-curriculum/',
#  'https://mothership.sg/2020/09/mental-health-during-covid-19/',
#  'https://mothership.sg/2019/10/mental-health-ncss/',
#  'https://mothership.sg/2020/12/naked-woman-at-bedok/',
#  'https://mothership.sg/2017/06/prince-harrys-frank-conversation-with-local-youths-on-mental-health-is-something-we-can-learn-from/',
#  'https://mothership.sg/2018/01/aunties-singapore-parkour/',
#  'https://mothership.sg/2017/11/nearly-10-of-spore-residents-will-suffer-from-mental-health-issues-more-support-to-reduce-social-stigma/',
#  'https://mothership.sg/2019/03/cpf-mental-health-treatment-savings/']

# %%
title2 = []
url_keep2 = []
date2 = []
text2 = []
keyfound2 = []

# %%
related_urls_3 = []
for url in url_mental:
    get_covid_news(url,related_urls_3)
related_urls_3
# Out:
# ['https://mothership.sg/2021/07/covid-19-survey-singaporeans-mental-health/',
#  'https://mothership.sg/2020/10/pm-lee-covid-19-mental-health/',
#  'https://mothership.sg/2020/08/migrant-workers-mental-health-mom/',
#  'https://mothership.sg/2020/11/chng-kai-fong/',
#  'https://mothership.sg/2020/09/migrant-worker-mental-health/',
#  'https://mothership.sg/2020/09/mental-health-during-covid-19/']

# %%
for url in related_urls_3:
    get_data(url,keywords,title2,url_keep2,date2,text2,keyfound2)
d3 = process_data(title2,url_keep2,date2,text2,keyfound2)

# %%
d3
# Out:
#                                             headline  \
# 0  PM Lee: New mental health task force to tackle...
# 1  MOM steps up efforts to care for migrant worke...
# 2  Feeling 'heat & anger': EDB chief opens up abo...
# 3  Helplines & migrant worker ambassadors help ad...
# 4  It’s okay to struggle with your mental health ...
#
#                                                  url  \
# 0  https://mothership.sg/2020/10/pm-lee-covid-19-...
# 1  https://mothership.sg/2020/08/migrant-workers-...
# 2       https://mothership.sg/2020/11/chng-kai-fong/
# 3  https://mothership.sg/2020/09/migrant-worker-m...
# 4  https://mothership.sg/2020/09/mental-health-du...
#
#                             date  \
# 0    October 11, 2020, 02:04 PM
# 1     August 06, 2020, 03:36 PM
# 2   November 23, 2020, 09:12 PM
# 3  September 05, 2020, 07:21 PM
# 4  September 30, 2020, 06:58 PM
#
#                                                 text  \
# 0   A new mental wellness task force has been est...
# 1   The Ministry of Manpower (MOM) has stepped up...
# 2   A top bureaucrat in Singapore has opened up a...
# 3   The manpower ministry has measures in place t...
# 4   While everyone is busy looking after their ph...
#
#                                             keywords
# 0  [stress, mental health, mental health, emotion...
# 1  [stress, isolation, isolation, suicide, mental...
# 2  [stress, mental health, mental health, emotion...
# 3  [stress, isolation, counselling, mental health...
# 4       [stress, mental health, mental health, help]

# %%
import openpyxl

path = 'Mothership_scrapings.xlsx'

with pd.ExcelWriter(path) as writer:
    d1.to_excel(writer, sheet_name='sheet1')
    d2.to_excel(writer, sheet_name='sheet2')
    d3.to_excel(writer, sheet_name='sheet3')
